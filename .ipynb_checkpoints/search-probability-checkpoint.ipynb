# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# df = pd.concat([pd.read_pickle("./uti/utiTrain.pkl"), pd.read_pickle("./utiTest.pkl")])
# use just training (screening) data
df = pd.read_pickle("./search/searchTrain.pkl")
# Shuffle df
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    code                                           abstract  \
# 0     0  The aim of this research review was to answer ...
# 1     0  A 2011 Cochrane Review found that adequately r...
# 2     0  OBJECTIVE: Mixed studies reviews include empir...
# 3     0  There is an intensive on-going research on sem...
# 4     0  Research into information retrieval (IR) canno...
#
#                                              scibert
# 0  [0.2455986, 0.005128092, -0.08977775, 0.404868...
# 1  [0.11787122, -0.38087252, -0.10598281, 0.50246...
# 2  [0.120171465, -0.15883973, -0.31733495, 0.2006...
# 3  [0.26621953, -0.15296112, -0.102132544, 0.3353...
# 4  [0.3141926, -0.11244135, -0.24975908, 0.206361...

# %% [markdown]
# # Helper Functions

# %%
# Function to plot confusion matrix
def plotConfMatrix(actual, pred, labels):
    conf_matrix = confusion_matrix(actual, pred)
    labels = ["Exclude", "Include"]
    df_cm = pd.DataFrame(conf_matrix, columns=labels, index=labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (4,2))
    sns.set(font_scale=1.2)#for label size
    sns.heatmap(df_cm, fmt='d', cmap="Blues", annot=True, annot_kws={"size": 12})# font size
    plt.show()
    return
 
# Function to calculate probabilities of each remaining article
def calcProb(model, initial, remaining):
    # Get initial training data and labels 
    initial_data = initial['scibert'].tolist()
    initial_labels = initial['code'].tolist()

    # Fit model to initial training data
    model.fit(initial_data, initial_labels)

    # Get remaining data for testing
    remaining_data = remaining['scibert'].tolist()

    # Predict probability [exclusion, inclusion] on remaining articles
    pred = model.predict_proba(remaining_data)

    # Calculate score (positive = exclude, negative = include)
    pred = list(map(lambda x: x[0]-x[1], pred))
    # Add probability to dataframe
    remaining['prob'] = pred
    # Sort by probability
    remaining = remaining.sort_values(by=['prob']).reset_index(drop=True)
    
    return remaining

# Calculate the total number of articles screened so far (train / train + test)
def calcPercentScreened(initial, remaining):
    return (initial.index[-1] + 1) / ((remaining.index[-1] + 1) + (initial.index[-1] + 1))

# Calculate the number of articles needed to screen out of entire dataset to find all included articles
# (train + last_index / train + test)
def calcPercentNeedToScreen(initial, remaining, last_index):
    return ((initial.index[-1] + 1) + (last_index + 1)) / ((initial.index[-1] + 1) + (remaining.index[-1] + 1))

# Print stats (return false when all included articles found)
def printStats(initial, remaining):
    # Find index of last included article
    include_indicies = remaining[remaining.code == 1].index
    # Calculate total percentage of articles that need to be screened
    if (len(include_indicies) == 0):
        print("All included articles found after screening: %.2f" % (calcPercentScreened(initial, remaining) * 100))
        return False
    else:
        print("Screened: %.2f Need to screen: %.2f" % (calcPercentScreened(initial, remaining) * 100, calcPercentNeedToScreen(initial, remaining, include_indicies[-1]) * 100))
        return True

# %% [markdown]
# # Iterative Predition using Probabilities

# %%
# model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)
model = LogisticRegression()

all_data = df['scibert'].tolist()
all_labels = df['code'].tolist()

# Find first included article index
start = df[df.code == 1].index[0] + 1
print("Initial number screened:", start)

# Split df by minimum size to screen
initial = df.iloc[:start,:].reset_index(drop=True)
remaining = df.iloc[start:,:].reset_index(drop=True)

while(remaining.index[-1] > 0):
    remaining = calcProb(model, initial, remaining)
    if(not printStats(initial, remaining)):
        break
    # Take first remaining and append to initial (to account for extra screened article)
    initial = initial.append(remaining.iloc[0], ignore_index=True)
    remaining.drop(0, inplace=True)
# Out:
# Initial number screened: 81
# Screened: 5.74 Need to screen: 93.69
# Screened: 5.81 Need to screen: 92.06
# Screened: 5.88 Need to screen: 90.36
# Screened: 5.95 Need to screen: 90.08
# Screened: 6.02 Need to screen: 91.35
# Screened: 6.09 Need to screen: 92.49
# Screened: 6.17 Need to screen: 74.84
# Screened: 6.24 Need to screen: 75.83
# Screened: 6.31 Need to screen: 77.53
# Screened: 6.38 Need to screen: 75.12
# Screened: 6.45 Need to screen: 71.72
# Screened: 6.52 Need to screen: 68.39
# Screened: 6.59 Need to screen: 67.82
# Screened: 6.66 Need to screen: 67.04
# Screened: 6.73 Need to screen: 58.61
# Screened: 6.80 Need to screen: 62.79
# Screened: 6.87 Need to screen: 62.65
# Screened: 6.95 Need to screen: 72.79
# Screened: 7.02 Need to screen: 68.75
# Screened: 7.09 Need to screen: 64.99
# Screened: 7.16 Need to screen: 66.97
# Screened: 7.23 Need to screen: 55.28
# Screened: 7.30 Need to screen: 56.91
# Screened: 7.37 Need to screen: 63.43
# Screened: 7.44 Need to screen: 69.74
# Screened: 7.51 Need to screen: 60.88
# Screened: 7.58 Need to screen: 58.61
# Screened: 7.65 Need to screen: 42.81
# Screened: 7.73 Need to screen: 48.19
# Screened: 7.80 Need to screen: 49.82
# Screened: 7.87 Need to screen: 50.18
# Screened: 7.94 Need to screen: 50.04
# Screened: 8.01 Need to screen: 49.54
# Screened: 8.08 Need to screen: 48.26
# Screened: 8.15 Need to screen: 47.63
# Screened: 8.22 Need to screen: 39.19
# Screened: 8.29 Need to screen: 34.73
# Screened: 8.36 Need to screen: 40.47
# Screened: 8.43 Need to screen: 38.27
# Screened: 8.50 Need to screen: 40.82
# Screened: 8.58 Need to screen: 37.70
# Screened: 8.65 Need to screen: 35.58
# Screened: 8.72 Need to screen: 30.55
# Screened: 8.79 Need to screen: 31.96
# Screened: 8.86 Need to screen: 31.61
# Screened: 8.93 Need to screen: 35.51
# Screened: 9.00 Need to screen: 34.44
# Screened: 9.07 Need to screen: 40.18
# Screened: 9.14 Need to screen: 40.61
# Screened: 9.21 Need to screen: 41.53
# Screened: 9.28 Need to screen: 44.22
# Screened: 9.36 Need to screen: 43.44
# Screened: 9.43 Need to screen: 46.63
# Screened: 9.50 Need to screen: 44.15
# Screened: 9.57 Need to screen: 45.78
# Screened: 9.64 Need to screen: 44.37
# Screened: 9.71 Need to screen: 44.37
# Screened: 9.78 Need to screen: 42.95
# Screened: 9.85 Need to screen: 40.26
# Screened: 9.92 Need to screen: 40.75
# Screened: 9.99 Need to screen: 43.44
# Screened: 10.06 Need to screen: 44.86
# Screened: 10.13 Need to screen: 48.05
# Screened: 10.21 Need to screen: 44.79
# Screened: 10.28 Need to screen: 41.18
# Screened: 10.35 Need to screen: 42.45
# Screened: 10.42 Need to screen: 41.81
# Screened: 10.49 Need to screen: 42.45
# Screened: 10.56 Need to screen: 26.65
# Screened: 10.63 Need to screen: 26.93
# Screened: 10.70 Need to screen: 25.73
# Screened: 10.77 Need to screen: 25.44
# Screened: 10.84 Need to screen: 25.66
# Screened: 10.91 Need to screen: 26.79
# Screened: 10.99 Need to screen: 26.22
# Screened: 11.06 Need to screen: 25.94
# Screened: 11.13 Need to screen: 26.29
# Screened: 11.20 Need to screen: 28.21
# Screened: 11.27 Need to screen: 30.83
# Screened: 11.34 Need to screen: 31.89
# Screened: 11.41 Need to screen: 31.11
# Screened: 11.48 Need to screen: 32.25
# Screened: 11.55 Need to screen: 31.54
# Screened: 11.62 Need to screen: 32.67
# Screened: 11.69 Need to screen: 35.44
# Screened: 11.76 Need to screen: 27.14
# Screened: 11.84 Need to screen: 28.07
# Screened: 11.91 Need to screen: 26.51
# Screened: 11.98 Need to screen: 28.21
# Screened: 12.05 Need to screen: 29.20
# Screened: 12.12 Need to screen: 29.77
# Screened: 12.19 Need to screen: 28.56
# Screened: 12.26 Need to screen: 29.41
# Screened: 12.33 Need to screen: 30.47
# Screened: 12.40 Need to screen: 31.18
# Screened: 12.47 Need to screen: 30.47
# Screened: 12.54 Need to screen: 29.91
# Screened: 12.62 Need to screen: 30.05
# Screened: 12.69 Need to screen: 29.41
# Screened: 12.76 Need to screen: 30.62
# Screened: 12.83 Need to screen: 29.91
# Screened: 12.90 Need to screen: 32.18
# Screened: 12.97 Need to screen: 32.88
# Screened: 13.04 Need to screen: 33.10
# Screened: 13.11 Need to screen: 49.33
# Screened: 13.18 Need to screen: 48.69
# Screened: 13.25 Need to screen: 47.98
# Screened: 13.32 Need to screen: 48.76
# Screened: 13.39 Need to screen: 47.98
# Screened: 13.47 Need to screen: 49.18
# Screened: 13.54 Need to screen: 47.55
# Screened: 13.61 Need to screen: 47.27
# Screened: 13.68 Need to screen: 47.27
# Screened: 13.75 Need to screen: 46.99
# Screened: 13.82 Need to screen: 46.21
# Screened: 13.89 Need to screen: 46.07
# Screened: 13.96 Need to screen: 46.28
# Screened: 14.03 Need to screen: 46.00
# Screened: 14.10 Need to screen: 45.57
# Screened: 14.17 Need to screen: 44.93
# Screened: 14.25 Need to screen: 45.15
# Screened: 14.32 Need to screen: 44.65
# Screened: 14.39 Need to screen: 45.15
# Screened: 14.46 Need to screen: 44.86
# Screened: 14.53 Need to screen: 45.00
# Screened: 14.60 Need to screen: 45.07
# Screened: 14.67 Need to screen: 44.86
# Screened: 14.74 Need to screen: 44.08
# Screened: 14.81 Need to screen: 44.37
# Screened: 14.88 Need to screen: 44.93
# Screened: 14.95 Need to screen: 44.65
# Screened: 15.02 Need to screen: 44.15
# Screened: 15.10 Need to screen: 44.15
# Screened: 15.17 Need to screen: 43.73
# Screened: 15.24 Need to screen: 44.01
# Screened: 15.31 Need to screen: 44.08
# Screened: 15.38 Need to screen: 44.15
# Screened: 15.45 Need to screen: 43.94
# Screened: 15.52 Need to screen: 44.22
# Screened: 15.59 Need to screen: 44.15
# Screened: 15.66 Need to screen: 44.79
# Screened: 15.73 Need to screen: 44.58
# Screened: 15.80 Need to screen: 44.22
# Screened: 15.88 Need to screen: 43.73
# Screened: 15.95 Need to screen: 43.23
# Screened: 16.02 Need to screen: 43.09
# Screened: 16.09 Need to screen: 43.16
# Screened: 16.16 Need to screen: 42.81
# Screened: 16.23 Need to screen: 44.22
# Screened: 16.30 Need to screen: 44.22
# Screened: 16.37 Need to screen: 44.22
# Screened: 16.44 Need to screen: 44.44
# Screened: 16.51 Need to screen: 44.72
# Screened: 16.58 Need to screen: 44.72
# Screened: 16.65 Need to screen: 44.44
# Screened: 16.73 Need to screen: 43.94
# Screened: 16.80 Need to screen: 45.78
# Screened: 16.87 Need to screen: 46.07
# Screened: 16.94 Need to screen: 45.57
# Screened: 17.01 Need to screen: 44.79
# Screened: 17.08 Need to screen: 44.93
# Screened: 17.15 Need to screen: 44.86
# Screened: 17.22 Need to screen: 44.86
# Screened: 17.29 Need to screen: 45.07
# Screened: 17.36 Need to screen: 44.79
# Screened: 17.43 Need to screen: 45.00
# Screened: 17.51 Need to screen: 36.71
# Screened: 17.58 Need to screen: 36.71
# Screened: 17.65 Need to screen: 36.64
# Screened: 17.72 Need to screen: 37.35
# Screened: 17.79 Need to screen: 37.07
# Screened: 17.86 Need to screen: 37.14
# Screened: 17.93 Need to screen: 37.14
# Screened: 18.00 Need to screen: 36.92
# Screened: 18.07 Need to screen: 36.85
# Screened: 18.14 Need to screen: 36.50
# Screened: 18.21 Need to screen: 36.57
# Screened: 18.28 Need to screen: 37.28
# Screened: 18.36 Need to screen: 37.14
# Screened: 18.43 Need to screen: 36.71
# Screened: 18.50 Need to screen: 37.07
# Screened: 18.57 Need to screen: 36.78
# Screened: 18.64 Need to screen: 36.78
# Screened: 18.71 Need to screen: 36.64
# Screened: 18.78 Need to screen: 36.57
# Screened: 18.85 Need to screen: 36.29
# Screened: 18.92 Need to screen: 36.29
# Screened: 18.99 Need to screen: 36.36
# Screened: 19.06 Need to screen: 36.29
# Screened: 19.14 Need to screen: 35.79
# Screened: 19.21 Need to screen: 35.72
# Screened: 19.28 Need to screen: 35.44
# Screened: 19.35 Need to screen: 35.44
# Screened: 19.42 Need to screen: 35.22
# Screened: 19.49 Need to screen: 35.22
# Screened: 19.56 Need to screen: 35.51
# Screened: 19.63 Need to screen: 35.15
# Screened: 19.70 Need to screen: 35.29
# Screened: 19.77 Need to screen: 35.29
# Screened: 19.84 Need to screen: 35.22
# Screened: 19.91 Need to screen: 35.29
# Screened: 19.99 Need to screen: 35.29
# Screened: 20.06 Need to screen: 35.22
# Screened: 20.13 Need to screen: 35.29
# Screened: 20.20 Need to screen: 35.29
# Screened: 20.27 Need to screen: 35.51
# Screened: 20.34 Need to screen: 35.36
# Screened: 20.41 Need to screen: 35.29
# Screened: 20.48 Need to screen: 35.29
# Screened: 20.55 Need to screen: 35.58
# Screened: 20.62 Need to screen: 35.36
# Screened: 20.69 Need to screen: 35.79
