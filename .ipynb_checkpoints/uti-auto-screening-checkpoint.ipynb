# %% [markdown]
# # Parse XML

# %%
# Imports
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

from xml.dom import minidom

# %%
#Function to parse xml
def parseXML(filename, isInclude):
    abstracts = []
    tags = []
    xmldoc = minidom.parse(filename)
    itemlist = xmldoc.getElementsByTagName('abstract')
    for node in xmldoc.getElementsByTagName('abstract'):
        abstract = node.getElementsByTagName('style')[0].firstChild.nodeValue
        abstracts.append(abstract)
        tags.append(isInclude)  
    return abstracts, tags

# %%
abstractsInclude, tagsInclude = parseXML('./uti/utiTestInclude.xml', 1)
abstractsExclude, tagsExclude = parseXML('./uti/utiTestExclude.xml', 0)
df = pd.DataFrame(list(zip(tagsInclude + tagsExclude, abstractsInclude + abstractsExclude)), 
               columns =['code', 'abstract'])
df.head()
# Out:
#    code                                           abstract
# 0     1  Purpose: We compared the effects of daily cran...
# 1     1  Background: The cranberry produces antimicrobi...
# 2     1  PURPOSE: To determine, from a societal perspec...
# 3     1  Urinary tract infections (UTIs) are an economi...
# 4     1  Aims: Radical pelvic radiotherapy is one of th...

# %% [markdown]
# # Load Sci-BERT Model

# %%
from transformers import BertModel, BertTokenizer
import torch
import numpy as np

scibert_model = BertModel.from_pretrained("allenai/scibert_scivocab_uncased",
                                  output_hidden_states=True)
scibert_tokenizer = BertTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")

print('scibert_tokenizer is type:', type(scibert_tokenizer))
print('    scibert_model is type:', type(scibert_model))

# %% [markdown]
# # Calculate Embeddings using Sci-BERT

# %%
def get_embedding(model, tokenizer, text):

    # Encode with special tokens ([CLS] and [SEP], returning pytorch tensors
    encoded_dict = tokenizer.encode_plus(
                        text,
                        truncation=True,
                        max_length=512,
                        add_special_tokens = True,
                        return_tensors = 'pt'
                )

    input_ids = encoded_dict['input_ids']
    
    # Set model to evaluation mode
    model.eval()
    
    # Run through BERT
    with torch.no_grad():

        outputs = model(input_ids)

        # Extract hidden states
        hidden_states = outputs[2]

    # Select the embeddings
    token_vecs = hidden_states[-2][0]

    # Calculate average of token vectors
    sentence_embedding = torch.mean(token_vecs, dim=0)

    # Convert to np array
    sentence_embedding = sentence_embedding.detach().numpy()

    return sentence_embedding

# %%
from IPython.display import clear_output
import timeit

embeddings = []
length = len(df['abstract'].tolist())
index = 0

start = timeit.default_timer()
for sentence in df['abstract'].tolist():
    clear_output(wait=True)
    index += 1
    sen_emb = get_embedding(scibert_model, scibert_tokenizer, sentence)
    embeddings.append(sen_emb)

    stop = timeit.default_timer()

    if (index/length*100) < 1:
        expected_time = "Calculating..."

    else:
        time_perc = timeit.default_timer()
        expected_time = np.round( (time_perc-start) /(index/length) /60,2)

    print(index, length)
    print(expected_time)

    
# Append to dataframe
df['scibert'] = embeddings
# Save dataframe to prevent recalculation
df.to_pickle("./utiTest.pkl")
df.head()

# %% [markdown]
# # Train Model

# %%
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
import seaborn as sns

def plotConfMatrix(actual, pred, labels):
    conf_matrix = confusion_matrix(actual, pred)
    labels = ["Exclude", "Include"]
    df_cm = pd.DataFrame(conf_matrix, columns=labels, index=labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (4,2))
    sns.set(font_scale=1.2)#for label size
    sns.heatmap(df_cm, fmt='d', cmap="Blues", annot=True, annot_kws={"size": 12})# font size
    plt.show()

# %%
df = pd.read_pickle("./uti//utiTrain.pkl")
df = df.sample(frac=1)
df.head()

train_data = df['scibert'].tolist()
train_labels = df['code'].tolist()

model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

model.fit(train_data, train_labels)
pred = model.predict(train_data)

labels = ["Exclude", "Include"]
plotConfMatrix(train_labels, pred, labels)

# %% [markdown]
# # Test Model

# %%
df = pd.read_pickle("./utiTest.pkl")
df = df.sample(frac=1)
df.head()

test_data = df['scibert'].tolist()
test_labels = df['code'].tolist()

pred = model.predict(test_data)

labels = ["Exclude", "Include"]
plotConfMatrix(test_labels, pred, labels)

# %% [markdown]
# # Random Test/Train Split

# %%
from sklearn.model_selection import train_test_split

df = pd.concat([pd.read_pickle("./uti/utiTrain.pkl"), pd.read_pickle("./utiTest.pkl")])
df = df.sample(frac=1)

train, test = train_test_split(df, test_size=0.2)

# %%
train_data = train['scibert'].tolist()
train_labels = train['code'].tolist()

model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

model.fit(train_data, train_labels)
pred = model.predict(train_data)

labels = ["Exclude", "Include"]
plotConfMatrix(train_labels, pred, labels)

# %%
test_data = test['scibert'].tolist()
test_labels = test['code'].tolist()

pred = model.predict(test_data)

labels = ["Exclude", "Include"]
plotConfMatrix(test_labels, pred, labels)

# %%
train, test = train_test_split(df, test_size=0.5)

train_data = train['scibert'].tolist()
train_labels = train['code'].tolist()

model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

model.fit(train_data, train_labels)
pred = model.predict(train_data)

labels = ["Exclude", "Include"]
plotConfMatrix(train_labels, pred, labels)

test_data = test['scibert'].tolist()
test_labels = test['code'].tolist()

pred = model.predict(test_data)

labels = ["Exclude", "Include"]
plotConfMatrix(test_labels, pred, labels)

# %%
train, test = train_test_split(df, test_size=0.7)

train_data = train['scibert'].tolist()
train_labels = train['code'].tolist()

model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

model.fit(train_data, train_labels)
pred = model.predict(train_data)

labels = ["Exclude", "Include"]
plotConfMatrix(train_labels, pred, labels)

test_data = test['scibert'].tolist()
test_labels = test['code'].tolist()

pred = model.predict(test_data)

labels = ["Exclude", "Include"]
plotConfMatrix(test_labels, pred, labels)

# %%
train, test = train_test_split(df, test_size=0.8)

train_data = train['scibert'].tolist()
train_labels = train['code'].tolist()

model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

model.fit(train_data, train_labels)
pred = model.predict(train_data)

labels = ["Exclude", "Include"]
plotConfMatrix(train_labels, pred, labels)

test_data = test['scibert'].tolist()
test_labels = test['code'].tolist()

pred = model.predict(test_data)

labels = ["Exclude", "Include"]
plotConfMatrix(test_labels, pred, labels)

# %%
train, test = train_test_split(df, test_size=0.9)

train_data = train['scibert'].tolist()
train_labels = train['code'].tolist()

model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

model.fit(train_data, train_labels)
pred = model.predict(train_data)

labels = ["Exclude", "Include"]
plotConfMatrix(train_labels, pred, labels)

test_data = test['scibert'].tolist()
test_labels = test['code'].tolist()

pred = model.predict(test_data)

labels = ["Exclude", "Include"]
plotConfMatrix(test_labels, pred, labels)

# %%
train, test = train_test_split(df, test_size=0.9)

train_data = train['scibert'].tolist()
train_labels = train['code'].tolist()

model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

model.fit(train_data, train_labels)
pred = model.predict(train_data)

labels = ["Exclude", "Include"]
plotConfMatrix(train_labels, pred, labels)

test_data = test['scibert'].tolist()
test_labels = test['code'].tolist()

# Predict probability [exclusion, inclusion]
pred = model.predict_proba(test_data)
# Calculate score (positive = exclude, negative = include)
def score(i):
    return i[0] - i[1]
pred = list(map(score, pred))
pred = model.predict(test_data)
print(pred)
# Out:
# [[0.6121254  0.3878746 ]
#  [0.93081572 0.06918428]
#  [0.78206634 0.21793366]
#  ...
#  [0.80812652 0.19187348]
#  [0.67947442 0.32052558]
#  [0.7779393  0.2220607 ]]
# [0.2242507934664389, 0.8616314319399174, 0.5641326823801764, -0.013313307839213806, 0.6883087172014806, 0.6220384611188841, 0.6191712607604587, 0.9211804641311028, 0.4522733904424579, 0.22220848007135197, 0.8071238029958934, 0.9633020600400968, 0.724023686997892, 0.5850966382814988, 0.7327041553778335, 0.0291154022338711, 0.3814032738929105, 0.3546092120316278, 0.4659704838772262, 0.902981164255622, 0.6300060061988959, 0.6097337801700242, 0.7926678844455164, 0.7540079849255847, -0.3176489253856378, 0.9044300959453759, 0.15310517617063407, 0.938339895024302, 0.5342599788728635, 0.7752042642005237, 0.5763506726034326, 0.954062865554121, 0.322989243125424, 0.8245798266727318, 0.5916247099905492, 0.4439399143325095, 0.6941505213045303, 0.9393403154856579, 0.8236185889264684, 0.6920265037353885, 0.8815351240708718, 0.8147635062395819, 0.15310517617063407, 0.47358388216709496, 0.4831139862843461, 0.7003642053705388, 0.7880151263361854, 0.8490107711960042, 0.10363336025107689, 0.014556510697775471, -0.04989368344902689, 0.21154516539970936, 0.5460638220590426, 0.7534664534231599, 0.5342599788728635, 0.572673866386409