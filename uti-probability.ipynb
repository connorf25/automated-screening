# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# df = pd.concat([pd.read_pickle("./uti/utiTrain.pkl"), pd.read_pickle("./utiTest.pkl")])
# use just training (screening) data
df = pd.read_pickle("./uti/utiTrain.pkl")
# Shuffle df
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    code                                           abstract  \
# 0     0  A randomized, placebo-controlled, double-blind...
# 1     0  One hundred women who underwent vaginal hyster...
# 2     0  Screening for bacteriuria by culture of voided...
# 3     0  In a randomized, double-blind clinical trial, ...
# 4     0  BACKGROUND: The aim of this study is to compar...
#
#                                              scibert
# 0  [0.41320926, -0.3184793, 0.016785104, 0.625384...
# 1  [0.2548079, -0.6519264, -0.20492533, 0.2531292...
# 2  [0.14358793, -0.2668293, -0.3464644, 0.3380412...
# 3  [0.1024194, -0.43026537, -0.34492365, 0.208245...
# 4  [0.102118134, 0.23197177, -0.12228052, 0.75677...

# %% [markdown]
# # Helper Functions

# %%
# Function to plot confusion matrix
def plotConfMatrix(actual, pred, labels):
    conf_matrix = confusion_matrix(actual, pred)
    labels = ["Exclude", "Include"]
    df_cm = pd.DataFrame(conf_matrix, columns=labels, index=labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (4,2))
    sns.set(font_scale=1.2)#for label size
    sns.heatmap(df_cm, fmt='d', cmap="Blues", annot=True, annot_kws={"size": 12})# font size
    plt.show()
    return
 
# Function to calculate probabilities of each remaining article
def calcProb(model, initial, remaining):
    # Get initial training data and labels 
    initial_data = initial['scibert'].tolist()
    initial_labels = initial['code'].tolist()

    # Fit model to initial training data
    model.fit(initial_data, initial_labels)

    # Get remaining data for testing
    remaining_data = remaining['scibert'].tolist()

    # Predict probability [exclusion, inclusion] on remaining articles
    pred = model.predict_proba(remaining_data)

    # Calculate score (positive = exclude, negative = include)
    pred = list(map(lambda x: x[0]-x[1], pred))
    # Add probability to dataframe
    remaining['prob'] = pred
    # Sort by probability
    remaining = remaining.sort_values(by=['prob']).reset_index(drop=True)
    
    return remaining

# Calculate the total number of articles screened so far (train / train + test)
def calcPercentScreened(initial, remaining):
    return (initial.index[-1] + 1) / ((remaining.index[-1] + 1) + (initial.index[-1] + 1))

# Calculate the number of articles needed to screen out of entire dataset to find all included articles
# (train + last_index / train + test)
def calcPercentNeedToScreen(initial, remaining, last_index):
    return ((initial.index[-1] + 1) + (last_index + 1)) / ((initial.index[-1] + 1) + (remaining.index[-1] + 1))

# Print stats (return false when all included articles found)
def printStats(initial, remaining):
    # Find index of last included article
    include_indicies = remaining[remaining.code == 1].index
    # Calculate total percentage of articles that need to be screened
    if (len(include_indicies) == 0):
        print("All included articles found after screening: %.2f" % (calcPercentScreened(initial, remaining) * 100))
        return False
    else:
        print("Screened: %.2f Need to screen: %.2f" % (calcPercentScreened(initial, remaining) * 100, calcPercentNeedToScreen(initial, remaining, include_indicies[-1]) * 100))
        return True

# %% [markdown]
# # Iterative Predition using Probabilities

# %%
model = LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)
all_data = df['scibert'].tolist()
all_labels = df['code'].tolist()

# Find first included article index
start = df[df.code == 1].index[0] + 1
print("Initial number screened:", start)

# Split df by minimum size to screen
initial = df.iloc[:start,:].reset_index(drop=True)
remaining = df.iloc[start:,:].reset_index(drop=True)

while(remaining.index[-1] > 0):
    remaining = calcProb(model, initial, remaining)
    if(not printStats(initial, remaining)):
        break
    # Take first remaining and append to initial (to account for extra screened article)
    initial = initial.append(remaining.iloc[0], ignore_index=True)
    remaining.drop(0, inplace=True)
# Out:
# Initial number screened: 18
# Screened: 1.63 Need to screen: 90.60
# Screened: 1.72 Need to screen: 90.24
# Screened: 1.81 Need to screen: 90.96
# Screened: 1.90 Need to screen: 91.14
# Screened: 1.99 Need to screen: 90.24
# Screened: 2.08 Need to screen: 90.05
# Screened: 2.17 Need to screen: 91.14
# Screened: 2.26 Need to screen: 91.32
# Screened: 2.35 Need to screen: 90.14
# Screened: 2.44 Need to screen: 89.96
# Screened: 2.53 Need to screen: 87.34
# Screened: 2.62 Need to screen: 86.44
# Screened: 2.71 Need to screen: 78.84
# Screened: 2.80 Need to screen: 72.51
# Screened: 2.89 Need to screen: 76.31
# Screened: 2.98 Need to screen: 79.20
# Screened: 3.07 Need to screen: 81.56
# Screened: 3.16 Need to screen: 81.19
# Screened: 3.25 Need to screen: 79.75
# Screened: 3.35 Need to screen: 79.93
# Screened: 3.44 Need to screen: 79.57
# Screened: 3.53 Need to screen: 80.47
# Screened: 3.62 Need to screen: 79.93
# Screened: 3.71 Need to screen: 79.75
# Screened: 3.80 Need to screen: 79.75
# Screened: 3.89 Need to screen: 79.02
# Screened: 3.98 Need to screen: 78.48
# Screened: 4.07 Need to screen: 77.76
# Screened: 4.16 Need to screen: 78.12
# Screened: 4.25 Need to screen: 79.11
# Screened: 4.34 Need to screen: 79.11
# Screened: 4.43 Need to screen: 78.75
# Screened: 4.52 Need to screen: 87.52
# Screened: 4.61 Need to screen: 89.51
# Screened: 4.70 Need to screen: 89.78
# Screened: 4.79 Need to screen: 89.96
# Screened: 4.88 Need to screen: 89.51
# Screened: 4.97 Need to screen: 88.79
# Screened: 5.06 Need to screen: 88.43
# Screened: 5.15 Need to screen: 88.43
# Screened: 5.24 Need to screen: 88.79
# Screened: 5.33 Need to screen: 88.79
# Screened: 5.42 Need to screen: 88.61
# Screened: 5.52 Need to screen: 88.43
# Screened: 5.61 Need to screen: 88.61
# Screened: 5.70 Need to screen: 89.42
# Screened: 5.79 Need to screen: 88.25
# Screened: 5.88 Need to screen: 88.25
# Screened: 5.97 Need to screen: 88.07
# Screened: 6.06 Need to screen: 88.25
# Screened: 6.15 Need to screen: 88.25
# Screened: 6.24 Need to screen: 87.88
# Screened: 6.33 Need to screen: 87.88
# Screened: 6.42 Need to screen: 88.07
# Screened: 6.51 Need to screen: 88.25
# Screened: 6.60 Need to screen: 88.25
# Screened: 6.69 Need to screen: 88.07
# Screened: 6.78 Need to screen: 87.07
# Screened: 6.87 Need to screen: 86.89
# Screened: 6.96 Need to screen: 87.07
# Screened: 7.05 Need to screen: 86.89
# Screened: 7.14 Need to screen: 86.71
# Screened: 7.23 Need to screen: 86.89
# Screened: 7.32 Need to screen: 87.07
# Screened: 7.41 Need to screen: 87.34
# Screened: 7.50 Need to screen: 86.71
# Screened: 7.59 Need to screen: 86.71
# Screened: 7.69 Need to screen: 87.70
# Screened: 7.78 Need to screen: 87.70
# Screened: 7.87 Need to screen: 87.70
# Screened: 7.96 Need to screen: 87.52
# Screened: 8.05 Need to screen: 87.70
# Screened: 8.14 Need to screen: 87.16
# Screened: 8.23 Need to screen: 86.98
# Screened: 8.32 Need to screen: 87.52
# Screened: 8.41 Need to screen: 87.52
# Screened: 8.50 Need to screen: 87.52
# Screened: 8.59 Need to screen: 87.70
# Screened: 8.68 Need to screen: 87.70
# Screened: 8.77 Need to screen: 87.70
# Screened: 8.86 Need to screen: 88.07
# Screened: 8.95 Need to screen: 87.88
# Screened: 9.04 Need to screen: 87.70
# Screened: 9.13 Need to screen: 88.07
# Screened: 9.22 Need to screen: 88.07
# Screened: 9.31 Need to screen: 88.61
# Screened: 9.40 Need to screen: 88.43
# Screened: 9.49 Need to screen: 88.43
# Screened: 9.58 Need to screen: 88.79
# Screened: 9.67 Need to screen: 88.61
# Screened: 9.76 Need to screen: 88.79
# Screened: 9.86 Need to screen: 88.61
# Screened: 9.95 Need to screen: 88.61
# Screened: 10.04 Need to screen: 88.61
# Screened: 10.13 Need to screen: 88.07
# Screened: 10.22 Need to screen: 88.25
# Screened: 10.31 Need to screen: 88.07
# Screened: 10.40 Need to screen: 88.61
# Screened: 10.49 Need to screen: 88.43
# Screened: 10.58 Need to screen: 88.61
# Screened: 10.67 Need to screen: 88.43
# Screened: 10.76 Need to screen: 88.43
# Screened: 10.85 Need to screen: 88.79
# Screened: 10.94 Need to screen: 88.79
# Screened: 11.03 Need to screen: 88.79
# Screened: 11.12 Need to screen: 88.97
# Screened: 11.21 Need to screen: 88.79
# Screened: 11.30 Need to screen: 88.25
# Screened: 11.39 Need to screen: 88.07
# Screened: 11.48 Need to screen: 88.79
# Screened: 11.57 Need to screen: 88.61
# Screened: 11.66 Need to screen: 88.61
# Screened: 11.75 Need to screen: 88.25
# Screened: 11.84 Need to screen: 88.07
# Screened: 11.93 Need to screen: 88.43
# Screened: 12.03 Need to screen: 88.43
# Screened: 12.12 Need to screen: 88.25
# Screened: 12.21 Need to screen: 88.61
# Screened: 12.30 Need to screen: 88.61
# Screened: 12.39 Need to screen: 88.61
# Screened: 12.48 Need to screen: 88.07
# Screened: 12.57 Need to screen: 88.07
# Screened: 12.66 Need to screen: 88.07
# Screened: 12.75 Need to screen: 88.07
# Screened: 12.84 Need to screen: 88.07
# Screened: 12.93 Need to screen: 88.25
# Screened: 13.02 Need to screen: 88.25
# Screened: 13.11 Need to screen: 88.25
# Screened: 13.20 Need to screen: 88.07
# Screened: 13.29 Need to screen: 88.07
# Screened: 13.38 Need to screen: 88.07
# Screened: 13.47 Need to screen: 88.07
# Screened: 13.56 Need to screen: 88.07
# Screened: 13.65 Need to screen: 88.25
# Screened: 13.74 Need to screen: 88.07
# Screened: 13.83 Need to screen: 88.25
# Screened: 13.92 Need to screen: 88.07
# Screened: 14.01 Need to screen: 88.07
# Screened: 14.10 Need to screen: 88.43
# Screened: 14.20 Need to screen: 88.43
# Screened: 14.29 Need to screen: 88.43
# Screened: 14.38 Need to screen: 88.25
# Screened: 14.47 Need to screen: 88.25
# Screened: 14.56 Need to screen: 88.07
# Screened: 14.65 Need to screen: 88.61
# Screened: 14.74 Need to screen: 88.61
# Screened: 14.83 Need to screen: 88.61
# Screened: 14.92 Need to screen: 88.61
# Screened: 15.01 Need to screen: 88.61
# Screened: 15.10 Need to screen: 88.61
# Screened: 15.19 Need to screen: 88.61
# Screened: 15.28 Need to screen: 88.61
# Screened: 15.37 Need to screen: 88.61
# Screened: 15.46 Need to screen: 88.61
# Screened: 15.55 Need to screen: 88.79
# Screened: 15.64 Need to screen: 88.79
# Screened: 15.73 Need to screen: 88.79
# Screened: 15.82 Need to screen: 88.79
# Screened: 15.91 Need to screen: 88.79
# Screened: 16.00 Need to screen: 78.48
# Screened: 16.09 Need to screen: 71.88
# Screened: 16.18 Need to screen: 73.42
# Screened: 16.27 Need to screen: 73.78
# Screened: 16.37 Need to screen: 74.14
# Screened: 16.46 Need to screen: 75.05
# Screened: 16.55 Need to screen: 75.23
# Screened: 16.64 Need to screen: 75.41
# Screened: 16.73 Need to screen: 75.41
# Screened: 16.82 Need to screen: 75.59
# Screened: 16.91 Need to screen: 77.03
# Screened: 17.00 Need to screen: 64.29
# Screened: 17.09 Need to screen: 59.76
# Screened: 17.18 Need to screen: 60.85
# Screened: 17.27 Need to screen: 61.57
# Screened: 17.36 Need to screen: 61.21
# Screened: 17.45 Need to screen: 61.21
# Screened: 17.54 Need to screen: 63.92
# Screened: 17.63 Need to screen: 69.17
# Screened: 17.72 Need to screen: 70.98
# Screened: 17.81 Need to screen: 71.70
# Screened: 17.90 Need to screen: 74.50
# Screened: 17.99 Need to screen: 76.40
# Screened: 18.08 Need to screen: 77.31
# Screened: 18.17 Need to screen: 77.31
# Screened: 18.26 Need to screen: 77.31
# Screened: 18.35 Need to screen: 77.85
# Screened: 18.44 Need to screen: 78.57
# Screened: 18.54 Need to screen: 80.74
# Screened: 18.63 Need to screen: 73.87
# Screened: 18.72 Need to screen: 70.52
# Screened: 18.81 Need to screen: 71.43
# Screened: 18.90 Need to screen: 72.24
# Screened: 18.99 Need to screen: 75.14
# Screened: 19.08 Need to screen: 74.95
# Screened: 19.17 Need to screen: 75.86
# Screened: 19.26 Need to screen: 75.86
# Screened: 19.35 Need to screen: 75.68
# Screened: 19.44 Need to screen: 76.04
# Screened: 19.53 Need to screen: 75.68
# Screened: 19.62 Need to screen: 75.50
# Screened: 19.71 Need to screen: 75.14
# Screened: 19.80 Need to screen: 76.76
# Screened: 19.89 Need to screen: 77.12
# Screened: 19.98 Need to screen: 77.67
# Screened: 20.07 Need to screen: 77.49
# Screened: 20.16 Need to screen: 77.31
# Screened: 20.25 Need to screen: 76.94
# Screened: 20.34 Need to screen: 78.03
# Screened: 20.43 Need to screen: 80.38
# Screened: 20.52 Need to screen: 80.02
# Screened: 20.61 Need to screen: 80.47
# Screened: 20.71 Need to screen: 80.02
# Screened: 20.80 Need to screen: 80.20
# Screened: 20.89 Need to screen: 78.75
# Screened: 20.98 Need to screen: 78.57
# Screened: 21.07 Need to screen: 77.12
# Screened: 21.16 Need to screen: 76.94
# Screened: 21.25 Need to screen: 76.94
# Screened: 21.34 Need to screen: 76.94
# Screened: 21.43 Need to screen: 76.94
# Screened: 21.52 Need to screen: 78.03
# Screened: 21.61 Need to screen: 78.93
# Screened: 21.70 Need to screen: 78.93
# Screened: 21.79 Need to screen: 78.75
# Screened: 21.88 Need to screen: 79.66
# Screened: 21.97 Need to screen: 78.39
# Screened: 22.06 Need to screen: 78.03
# Screened: 22.15 Need to screen: 78.75
# Screened: 22.24 Need to screen: 78.75
# Screened: 22.33 Need to screen: 78.39
# Screened: 22.42 Need to screen: 78.93
# Screened: 22.51 Need to screen: 75.05
# Screened: 22.60 Need to screen: 72.51
# Screened: 22.69 Need to screen: 60.94
# Screened: 22.78 Need to screen: 55.97
# Screened: 22.88 Need to screen: 56.33
# Screened: 22.97 Need to screen: 55.33
# Screened: 23.06 Need to screen: 55.79
# Screened: 23.15 Need to screen: 58.14
# Screened: 23.24 Need to screen: 58.41
# Screened: 23.33 Need to screen: 59.86
# Screened: 23.42 Need to screen: 60.22
# Screened: 23.51 Need to screen: 61.84
# Screened: 23.60 Need to screen: 61.30
# Screened: 23.69 Need to screen: 65.82
# Screened: 23.78 Need to screen: 65.64
# Screened: 23.87 Need to screen: 65.82
# Screened: 23.96 Need to screen: 49.64
# Screened: 24.05 Need to screen: 42.31
# Screened: 24.14 Need to screen: 43.94
# Screened: 24.23 Need to screen: 45.93
# Screened: 24.32 Need to screen: 47.38
# Screened: 24.41 Need to screen: 49.55
# Screened: 24.50 Need to screen: 50.45
# Screened: 24.59 Need to screen: 50.90
# Screened: 24.68 Need to screen: 50.90
# Screened: 24.77 Need to screen: 51.63
# Screened: 24.86 Need to screen: 53.07
# Screened: 24.95 Need to screen: 53.98
# Screened: 25.05 Need to screen: 54.43
# Screened: 25.14 Need to screen: 38.43
# Screened: 25.23 Need to screen: 39.60
# Screened: 25.32 Need to screen: 39.78
# Screened: 25.41 Need to screen: 38.43
# Screened: 25.50 Need to screen: 37.88
# Screened: 25.59 Need to screen: 37.34
# Screened: 25.68 Need to screen: 38.25
# Screened: 25.77 Need to screen: 38.07
# Screened: 25.86 Need to screen: 37.70
# Screened: 25.95 Need to screen: 37.16
# Screened: 26.04 Need to screen: 36.80
# Screened: 26.13 Need to screen: 36.98
# Screened: 26.22 Need to screen: 36.62
# Screened: 26.31 Need to screen: 36.44
# Screened: 26.40 Need to screen: 36.26
# Screened: 26.49 Need to screen: 36.26
# Screened: 26.58 Need to screen: 36.26
# Screened: 26.67 Need to screen: 36.26
# Screened: 26.76 Need to screen: 36.26
# Screened: 26.85 Need to screen: 36.62
# Screened: 26.94 Need to screen: 36.62
# Screened: 27.03 Need to screen: 35.90
# Screened: 27.12 Need to screen: 36.08
# Screened: 27.22 Need to screen: 36.08
# Screened: 27.31 Need to screen: 35.53
# Screened: 27.40 Need to screen: 35.71
# Screened: 27.49 Need to screen: 35.71
# Screened: 27.58 Need to screen: 35.71
# Screened: 27.67 Need to screen: 35.71
# Screened: 27.76 Need to screen: 35.71
# Screened: 27.85 Need to screen: 35.53
# Screened: 27.94 Need to screen: 35.71
# Screened: 28.03 Need to screen: 35.90
# Screened: 28.12 Need to screen: 35.90
# Screened: 28.21 Need to screen: 35.90
# Screened: 28.30 Need to screen: 36.44
# Screened: 28.39 Need to screen: 36.44
# Screened: 28.48 Need to screen: 36.44
# Screened: 28.57 Need to screen: 36.44
# Screened: 28.66 Need to screen: 36.08
# Screened: 28.75 Need to screen: 35.53
# Screened: 28.84 Need to screen: 35.71
# Screened: 28.93 Need to screen: 35.71
# Screened: 29.02 Need to screen: 35.90
# Screened: 29.11 Need to screen: 35.71
# Screened: 29.20 Need to screen: 35.90
# Screened: 29.29 Need to screen: 35.17
# Screened: 29.39 Need to screen: 35.35
# Screened: 29.48 Need to screen: 35.17
# Screened: 29.57 Need to screen: 35.35
# Screened: 29.66 Need to screen: 35.17
# Screened: 29.75 Need to screen: 35.17
# Screened: 29.84 Need to screen: 35.17
# Screened: 29.93 Need to screen: 35.17
# Screened: 30.02 Need to screen: 35.17
# Screened: 30.11 Need to screen: 35.17
# Screened: 30.20 Need to screen: 35.17
# Screened: 30.29 Need to screen: 35.17
# Screened: 30.38 Need to screen: 35.17
# Screened: 30.47 Need to screen: 35.17
# Screened: 30.56 Need to screen: 35.17
# Screened: 30.65 Need to screen: 35.17
# Screened: 30.74 Need to screen: 35.17
# Screened: 30.83 Need to screen: 35.53
# Screened: 30.92 Need to screen: 35.17
# Screened: 31.01 Need to screen: 35.35
# Screened: 31.10 Need to screen: 35.35
# Screened: 31.19 Need to screen: 35.53
# Screened: 31.28 Need to screen: 35.90
# Screened: 31.37 Need to screen: 35.71
# Screened: 31.46 Need to screen: 35.71
# Screened: 31.56 Need to screen: 35.53
# Screened: 31.65 Need to screen: 35.17
# Screened: 31.74 Need to screen: 35.17
# Screened: 31.83 Need to screen: 35.53
# Screened: 31.92 Need to screen: 35.53
# Screened: 32.01 Need to screen: 35.35
# Screened: 32.10 Need to screen: 35.53
# Screened: 32.19 Need to screen: 35.53
# Screened: 32.28 Need to screen: 38.70
# Screened: 32.37 Need to screen: 40.51
# Screened: 32.46 Need to screen: 40.14
# Screened: 32.55 Need to screen: 39.96
# Screened: 32.64 Need to screen: 39.96
# Screened: 32.73 Need to screen: 39.42
# Screened: 32.82 Need to screen: 39.42
# Screened: 32.91 Need to screen: 39.42
# Screened: 33.00 Need to screen: 39.42
# Screened: 33.09 Need to screen: 39.42
# Screened: 33.18 Need to screen: 39.51
# Screened: 33.27 Need to screen: 39.24
# Screened: 33.36 Need to screen: 39.24
# Screened: 33.45 Need to screen: 39.24
# Screened: 33.54 Need to screen: 38.70
# Screened: 33.63 Need to screen: 38.52
# Screened: 33.73 Need to screen: 38.52
# Screened: 33.82 Need to screen: 38.34
# Screened: 33.91 Need to screen: 38.34
# Screened: 34.00 Need to screen: 41.68
# Screened: 34.09 Need to screen: 44.85
# Screened: 34.18 Need to screen: 45.03
# Screened: 34.27 Need to screen: 45.21
# Screened: 34.36 Need to screen: 44.48
# Screened: 34.45 Need to screen: 44.48
# Screened: 34.54 Need to screen: 44.03
# Screened: 34.63 Need to screen: 43.49
# Screened: 34.72 Need to screen: 42.77
# Screened: 34.81 Need to screen: 42.95
# Screened: 34.90 Need to screen: 42.95
# Screened: 34.99 Need to screen: 42.95
# Screened: 35.08 Need to screen: 43.13
# Screened: 35.17 Need to screen: 43.13
# Screened: 35.26 Need to screen: 42.95
# Screened: 35.35 Need to screen: 42.77
# Screened: 35.44 Need to screen: 42.59
# Screened: 35.53 Need to screen: 42.77
# Screened: 35.62 Need to screen: 42.22
# Screened: 35.71 Need to screen: 42.41
# Screened: 35.80 Need to screen: 42.04
# Screened: 35.90 Need to screen: 42.04
# Screened: 35.99 Need to screen: 42.04
# Screened: 36.08 Need to screen: 42.04
# Screened: 36.17 Need to screen: 41.14
# Screened: 36.26 Need to screen: 41.14
# Screened: 36.35 Need to screen: 41.32
# Screened: 36.44 Need to screen: 41.68
# Screened: 36.53 Need to screen: 41.68
# Screened: 36.62 Need to screen: 41.14
# Screened: 36.71 Need to screen: 41.59
# Screened: 36.80 Need to screen: 41.59
# Screened: 36.89 Need to screen: 41.59
# Screened: 36.98 Need to screen: 40.96
# Screened: 37.07 Need to screen: 40.96
# Screened: 37.16 Need to screen: 41.59
# Screened: 37.25 Need to screen: 41.50
# Screened: 37.34 Need to screen: 41.50
# Screened: 37.43 Need to screen: 41.59
# Screened: 37.52 Need to screen: 41.50
# Screened: 37.61 Need to screen: 41.32
# Screened: 37.70 Need to screen: 41.32
# Screened: 37.79 Need to screen: 41.50
# Screened: 37.88 Need to screen: 41.32
# Screened: 37.97 Need to screen: 41.32
# Screened: 38.07 Need to screen: 41.32
# Screened: 38.16 Need to screen: 41.32
# Screened: 38.25 Need to screen: 41.32
# Screened: 38.34 Need to screen: 41.32
# Screened: 38.43 Need to screen: 41.32
# Screened: 38.52 Need to screen: 41.32
# Screened: 38.61 Need to screen: 41.77
# Screened: 38.70 Need to screen: 41.68
# Screened: 38.79 Need to screen: 41.77
# Screened: 38.88 Need to screen: 41.77
# Screened: 38.97 Need to screen: 41.68
# Screened: 39.06 Need to screen: 41.68
# Screened: 39.15 Need to screen: 41.68
# Screened: 39.24 Need to screen: 41.68
# Screened: 39.33 Need to screen: 41.86
# Screened: 39.42 Need to screen: 41.86
# Screened: 39.51 Need to screen: 41.86
# Screened: 39.60 Need to screen: 41.95
# Screened: 39.69 Need to screen: 42.13
# Screened: 39.78 Need to screen: 42.31
# Screened: 39.87 Need to screen: 42.13
# Screened: 39.96 Need to screen: 41.95
# Screened: 40.05 Need to screen: 42.31
# Screened: 40.14 Need to screen: 42.31
# Screened: 40.24 Need to screen: 42.31
# Screened: 40.33 Need to screen: 42.31
# Screened: 40.42 Need to screen: 41.95
# Screened: 40.51 Need to screen: 42.31
# Screened: 40.60 Need to screen: 41.86
# Screened: 40.69 Need to screen: 42.22
# Screened: 40.78 Need to screen: 41.95
# Screened: 40.87 Need to screen: 41.86
# Screened: 40.96 Need to screen: 41.86
# Screened: 41.05 Need to screen: 41.86
# Screened: 41.14 Need to screen: 41.86
# Screened: 41.23 Need to screen: 41.86
# Screened: 41.32 Need to screen: 41.77
# Screened: 41.41 Need to screen: 41.77
# Screened: 41.50 Need to screen: 41.86
# Screened: 41.59 Need to screen: 42.13
# Screened: 41.68 Need to screen: 42.68
# Screened: 41.77 Need to screen: 42.22
# Screened: 41.86 Need to screen: 42.04
# Screened: 41.95 Need to screen: 42.04
# All included articles found after screening: 42.04
